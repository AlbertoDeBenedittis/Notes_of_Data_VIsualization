# %% [markdown]
# # Exam July 2019

# %% [markdown]
# __[0-5 points] Describe in detail the three elements of graph understanding (perceiving/interpreting/comprehending), first in general and then applying these principles to the reading of the following plot:__
#
# Let's start by defining the type of chart we are dealing with: this is an area chart.
# * _Perceiving_: At a first glance, this chart recalls the image of a mountain. Indeed, what we see is an increasing trend until it reach the peak and the it start a descending. We also perceive 6 different colors but one is predominat, the blue navy. We may think that the association with a mountain is voluntary since the author has used terms as peak and valley.
# * _Interpreting_: From the plot we see that from 1977 to 2000 the music revenues have increased especially thanks to the introduction of technological novelties such as cassettes and compact discs, while after the 2000 there have been a slow declining in the music revenus arringin in 2017 where the revenues are mainly based on digital content.
# * _Cohmprehension_: The music sector has seen many different stages, firstly, there was the vynil that was particularly famous in the 20th century. Then due to technological development it was substituted by cassettes and especially by compact disks. This is due to the fact that it was a cheaper technology and it was more esy to transport and use. Thus, the revenius of compact disk are mainly based on the total amount of unit sold. The last and descending trend, is caused again by technological development. Indeed, with the digital era, fewer and fewer people buy 'phisical music' because it is mainly available on internt. Thus, the music revenues have drammatically decreased. However, recently, a new trend is growing. As a matter of fact people are nostalgic and they are appasionate to old stuff, as we can see with the small increase of vynil after year. Nevertheless, physical music is no loger competitive as before. Streaming is definitely the future. Thus company as spotify are increasing the prices for their subscriptions.

# %% [markdown]
# __[0-5 points] Describe in detail at least two chart types where a statistical quantity is graphically represented on a geographical map, clearly listing the differences between the two charts. For each of them, show an example.__
#
# * __Choropleth Map__: In a choroplet map each tile is colored to encode a variable. A tile represents a geographic region for, for example, counties and countries. Choropleth maps provide a good way to show how a variable varies across a geographic area. One thing to keep in mind for choropleth maps is that the human eye nutarally gives more prominence to larger areas, so you might want to normalize your data by dividing the map area-swise.
# * __Dot Map__: In a dot map each dot represents a certain number of observations. Each dot has the same size and value (each dot corresponds to an observation). The dots are not meant to be counted they are only intended to give an impression of the magnitude. The size and the vaues are important factors for the effectiveness and impression of the visualizations. You can use differnet colors or symbols for the dots to show multiple categories or group.

# %% [markdown]
# __[0-5 points] Describe the UMAP algorithm, highlighting its pros and cons; find a case study where UMAP is more appropriate than PCA.__
#  UMAP aka Uniform manyfold Approximation and projection.
# The last dimensionality reduction method is __UMAP__, uniform manifold approximation and projection.
# The underlying idea behind umap is to detect the manyfold geometrical structure where the points are leaving and tr to approximate it and project it in a two (three) dimensional space.
# Umap is basically done in two main steps: the graph construction (high dimension) and the graph projection (low dimension).
# The cool part of umap is that its steps are mathematically proven to work.
# Firstly, we have the data in high dimensional space and we want to approximate their shape/topology. Each point is called 0-simplex.
# Nerve theorem -> shape of data can be approximated when we connect the 0 simpleces with their nighbouring data point forming 1,2 or higher simpleces. With this we can approximate the topology.
# So what we need to do is making this connections. For this, the umap algorithm extends a radius around each point and makes a connection between each point and its neghbors with interseting radii.
# So far the radii are equal. But rember, we want to approximate the shape of the data, so we want a connceted graph containing all our data points. But this whish brings in two problems:
# * Firstly, it oftne happens that in the data there are larger gaps, where there is no next point to connect to in the graph. This usually happens in low density regions.
# * Secondly, there are often high density regions where there are a lot of neighbors in the given radius and everything is way to connected.
# The second problem becomes even worse with the _curse of dimensionality_, where in high dimensional spaces the distances between points become more and more similar.
# Thus, we can use instead equal radius, variable radius.
# This choice is mathematically supported by the definition of a _Riemannian metric_ on the manifold.
# To recap, in small density regions the radius is bigger while in high in high density regions the radius is smaller.
# Moreover, umap does not estimate density directly as a number but uses a proxy: the density is estimated to be higher when the kth neighbor is close and lower when the kth nearest neighbor is far away.
# As we know, the k is an hyperparameter that needs to be chosen:
# * k big -> more global structure is preserved
# * k small -> the radius decreases and the local structure is more preserved.
# So we need to wisely choose the k in order to achieve the perfect balance between the local and the global structure preservation.
# Unfortunately, there is not a magic receipes that allows us to find th optimal k automatically. We need the trial and error procedure.
# But not all k neighbors are equal, since each have different distances from the point we are looking at. Then the connections between each point and their neighbors get a weight, a connection probability, where points which are far away, are weighted less and get lower connection probability.
#
# Now our dimensional graph is constructed and it is ready to be projected to lower dimensions. We can imagine this projection as taking the high dimensional graph, with their edges being springs, where each spring is stronger as the edge probability increase.
# This means that poinys connected by high weighted edges are more likely to stay together in the lower dimensional space, because the spring holds these points together. And perhaps it is interesting to notice that soring forces are rotationally symmetric which lead to clusters sometimes landing on one side after one umap run and on the other side adter another projection.
#
# Compared to t-SNE, UMAP:
# * is faster due to its optimizations and strong mathematical foundations,
# * has a better balance between locality and globality in clustering.
#
# However, UMAP excels at reducing from a lot of dimensions. The most common example where we can compare the higher performance of UMAP compared to PCA occurs when we want to perform dimensionality reduction on the mnist dataset.

# %% [markdown]
# __[0-7 points] Find a data visualization (one or more plots) for the data in http://bit.ly/2FZQybB (or a subset of the data); justify your choice and find/comment one or more non-trivial relations among the data visible in the plot(s).__

# %%
import pandas as pd

# %%
data = pd.read_csv('renewable-energy-consumption.csv')

# %%
data
# Out:
#       Entity      Code  Year  Traditional biofuels (terrawatt-hours)  \
# 0     Africa       NaN  1965                                     NaN
# 1     Africa       NaN  1966                                     NaN
# 2     Africa       NaN  1967                                     NaN
# 3     Africa       NaN  1968                                     NaN
# 4     Africa       NaN  1969                                     NaN
# ...      ...       ...   ...                                     ...
# 4189   World  OWID_WRL  2013                             11330.08610
# 4190   World  OWID_WRL  2014                             11220.06442
# 4191   World  OWID_WRL  2015                             11111.11111
# 4192   World  OWID_WRL  2016                             11003.21580
# 4193   World  OWID_WRL  2017                             10895.32049
#
#       Other renewables (modern biofuels, geothermal, wave & tidal) (terawatt-hours)  \
# ...

# %%
data.Entity.unique()
# Out:
# array(['Africa', 'Algeria', 'Argentina', 'Asia Pacific', 'Australia',
#        'Austria', 'Azerbaijan', 'Bangladesh', 'Belarus', 'Belgium',
#        'Brazil', 'Bulgaria', 'CIS', 'Canada', 'Chile', 'China',
#        'Colombia', 'Czech Republic', 'Denmark', 'Ecuador', 'Egypt',
#        'Europe & Eurasia', 'European Union', 'Finland', 'France',
#        'Germany', 'Greece', 'Hong Kong', 'Hungary', 'India', 'Indonesia',
#        'Iran', 'Ireland', 'Israel', 'Italy', 'Japan', 'Kazakhstan',
#        'Kuwait', 'Lithuania', 'Malaysia', 'Mexico', 'Middle East',
#        'Netherlands', 'New Zealand', 'Non-OECD', 'North America',
#        'Norway', 'OECD', 'Other Africa', 'Other Asia Pacific',
#        'Other Europe & Eurasia', 'Other Middle East',
#        'Other South & Central America', 'Pakistan', 'Peru', 'Philippines',
#        'Poland', 'Portugal', 'Qatar', 'Romania', 'Russia', 'Saudi Arabia',
#        'Singapore', 'Slovakia', 'South & Central America', 'South Africa',
# ...

# %%
data.Year.unique()
# Out:
# array([1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975,
#        1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986,
#        1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#        1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#        2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 1800, 1810, 1820,
#        1830, 1840, 1850, 1860, 1870, 1880, 1890, 1900, 1910, 1920, 1930,
#        1940, 1950, 1960, 2017], dtype=int64)

# %%
type(data['Year'][0])
# Out:
# numpy.int64

# %%
data_17 = data[data['Year'] == 2017]
data_17
# Out:
#      Entity      Code  Year  Traditional biofuels (terrawatt-hours)  \
# 4193  World  OWID_WRL  2017                             10895.32049
#
#       Other renewables (modern biofuels, geothermal, wave & tidal) (terawatt-hours)  \
# 4193                                                NaN
#
#       Wind (Terawatt-hours)  Solar PV (Terawatt-hours)  Hydropower (TWh)
# 4193                    NaN                        NaN       4059.868393

# %%
data_nafree = data.dropna()
data_nafree
# Out:
#      Entity      Code  Year  Traditional biofuels (terrawatt-hours)  \
# 4141  World  OWID_WRL  1965                             9162.456946
# 4142  World  OWID_WRL  1966                             9218.172711
# 4143  World  OWID_WRL  1967                             9274.227277
# 4144  World  OWID_WRL  1968                             9330.622704
# 4145  World  OWID_WRL  1969                             9387.361065
# 4146  World  OWID_WRL  1970                             9444.444444
# 4147  World  OWID_WRL  1971                             9498.581964
# 4148  World  OWID_WRL  1972                             9553.029811
# 4149  World  OWID_WRL  1973                             9607.789765
# 4150  World  OWID_WRL  1974                             9662.863614
# 4151  World  OWID_WRL  1975                             9718.253158
# 4152  World  OWID_WRL  1976                             9773.960206
# 4153  World  OWID_WRL  1977                             9829.986579
# ...

# %% [markdown]
# Let's do a timeseries analysis where we consider each of the measures

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
data_nafree.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'Traditional biofuels (terrawatt-hours)',
#        'Other renewables (modern biofuels, geothermal, wave & tidal) (terawatt-hours)',
#        'Wind (Terawatt-hours)', 'Solar PV (Terawatt-hours)',
#        'Hydropower (TWh)'],
#       dtype='object')

# %%
col = [ 'Traditional biofuels (terrawatt-hours)',
       'Other renewables (modern biofuels, geothermal, wave & tidal) (terawatt-hours)',
       'Wind (Terawatt-hours)', 'Solar PV (Terawatt-hours)',
       'Hydropower (TWh)']
min_max = {}
for c in col:
    min_ = data_nafree[c].min()
    max_ = data_nafree[c].max()
    min_max[c] =(min_, max_)
min_max
# Out:
# {'Traditional biofuels (terrawatt-hours)': (9162.456946, 12500.0),
#  'Other renewables (modern biofuels, geothermal, wave & tidal) (terawatt-hours)': (5.02,
#   561.666064109647),
#  'Wind (Terawatt-hours)': (0.0, 959.5295060515964),
#  'Solar PV (Terawatt-hours)': (0.0, 333.0524925053244),
#  'Hydropower (TWh)': (919.7702757000001, 4036.073668)}

# %%
data_nafree.index
# Out:
# Int64Index([4141, 4142, 4143, 4144, 4145, 4146, 4147, 4148, 4149, 4150, 4151,
#             4152, 4153, 4154, 4155, 4156, 4157, 4158, 4159, 4160, 4161, 4162,
#             4163, 4164, 4165, 4166, 4167, 4168, 4169, 4170, 4171, 4172, 4173,
#             4174, 4175, 4176, 4177, 4178, 4179, 4180, 4181, 4182, 4183, 4184,
#             4185, 4186, 4187, 4188, 4189, 4190, 4191, 4192],
#            dtype='int64')

# %%
data_nafree.index.tolist()[::5]
# Out:
# [4141, 4146, 4151, 4156, 4161, 4166, 4171, 4176, 4181, 4186, 4191]

# %%
data_nafree.reset_index(inplace = True)

# %%
data_nafree
# Out:
#     index Entity      Code  Year  Traditional biofuels (terrawatt-hours)  \
# 0    4141  World  OWID_WRL  1965                             9162.456946
# 1    4142  World  OWID_WRL  1966                             9218.172711
# 2    4143  World  OWID_WRL  1967                             9274.227277
# 3    4144  World  OWID_WRL  1968                             9330.622704
# 4    4145  World  OWID_WRL  1969                             9387.361065
# 5    4146  World  OWID_WRL  1970                             9444.444444
# 6    4147  World  OWID_WRL  1971                             9498.581964
# 7    4148  World  OWID_WRL  1972                             9553.029811
# 8    4149  World  OWID_WRL  1973                             9607.789765
# 9    4150  World  OWID_WRL  1974                             9662.863614
# 10   4151  World  OWID_WRL  1975                             9718.253158
# 11   4152  World  OWID_WRL  1976                             9773.960206
# ...

# %%
len(data_nafree['Year'])
# Out:
# 52

# %%
year_l = data_nafree['Year'].to_list()
year_l
# Out:
# [1965,
#  1966,
#  1967,
#  1968,
#  1969,
#  1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016]

# %%
np.arange(0,len(data_nafree['Year']), 5)
# Out:
# array([ 0,  5, 10, 15, 20, 25, 30, 35, 40, 45, 50])

# %%
[str(year_l[i]) for i in range(0,len(year_l),5)]
# Out:
# ['1965',
#  '1970',
#  '1975',
#  '1980',
#  '1985',
#  '1990',
#  '1995',
#  '2000',
#  '2005',
#  '2010',
#  '2015']

# %%
df = data_nafree
# Draw Plot
plt.figure(figsize=(10,8), dpi= 80)
plt.plot('Traditional biofuels (terrawatt-hours)', data=df, color="tab:brown", label = 'Traditional biofuels')
plt.plot('Other renewables (modern biofuels, geothermal, wave & tidal) (terawatt-hours)', data=df, color="tab:red", label = 'modern biofuels, geothermal, wave & tidal')
plt.plot('Wind (Terawatt-hours)', data=df, color="tab:blue", label = 'Wind')
plt.plot('Solar PV (Terawatt-hours)', data=df, color="tab:orange", label = 'Solar PV')
plt.plot('Hydropower (TWh)', data=df, color="tab:grey", label = 'Hydropower')


# Decoration
plt.ylim(0, 15000)
# Date ticks
#xtick_location = df.index.tolist()[::5]
#xtick_labels = [x for x in df.Year.tolist()[::5]]
#plt.xticks(ticks=xtick_location, labels=xtick_labels, rotation=0, fontsize=12, horizontalalignment='center', alpha=.7)
plt.xticks(ticks=np.arange(0,len(df['Year']), 5), labels = [str(year_l[i]) for i in range(0,len(year_l), 5)]) 



plt.yticks(fontsize=12, alpha=.7)
plt.title("Consumption of renewable sources in terrawatt-hours", fontsize=22)
plt.grid(axis='both', alpha=.3)

# Remove borders
plt.gca().spines["top"].set_alpha(0.0)    
plt.gca().spines["bottom"].set_alpha(0.3)
plt.gca().spines["right"].set_alpha(0.0)    
plt.gca().spines["left"].set_alpha(0.3)   
plt.legend()
plt.show()

# %%
df_2016 = df[df['Year'] == 2016]

# %%
df_1965 = df[df['Year'] == 1965]

# %%
df_1965['Traditional biofuels (terrawatt-hours)'][0]
# Out:
# 9162.456946

# %%
df_2016['Traditional biofuels (terrawatt-hours)'].tolist()[0]
# Out:
# 11003.2158

# %%
tot_65 = 0
tot_16 = 0 
val_65 = []
val_16 = []
for x in col:
    
    val_65.append(df_1965[x].tolist()[0])
    val_16.append(df_2016[x].tolist()[0])
    tot_65 += df_1965[x].tolist()[0]
    tot_16 += df_2016[x].tolist()[0]

# %%
per_16 = []
per_65 = []
for j in range(len(val_65)):
    per_16.append(round(val_16[j]/tot_16,2))
    per_65.append(round(val_65[j]/tot_65,2))

# %%
per_16
# Out:
# [0.65, 0.03, 0.06, 0.02, 0.24]

# %%
# Create the figure
plt.figure(figsize = (8,8), dpi = 300)
# Create the pie plot
plt.pie(per_16,explode = (0.1,0,0,0,0),labels = col, autopct = '%0f%%')
# Add title
#plt.legend()
plt.title('Renewable sources consumption in 2016')
plt.show()

# %%
# Create the figure
plt.figure(figsize = (8,8), dpi = 300)
# Create the pie plot
plt.pie(per_65,explode = (0.1,0,0,0,0), labels = col, autopct = '%0f%%')
# Add title
#plt.legend()
plt.title('Renewable sources consumption in 2016')
plt.show()

# %% [markdown]
# Here we have produced 3 plots. A timeseries and two pieplot.
# With the timeseries, we are able to see how the consumption in absolute terms has changed. Indeed, 50 years ago many of the new reweable sources such as wind or solar power weren't used. However, although they consumption have increased they are still not comparable to the usage of traditional bio fuels.
# This can be better understood expecially if we take a look to the two pieplots. In the one of 1965 we see that traditional biofuels were almost the unique source of energy, hydropower constitutes a small part and all the others weren't used.
# In 2016 the situation is different, but traditional bio fuels are still the main player and they constitute more than half of the resources.

# %% [markdown]
# __The Wisconsin Breast Cancer dataset http://bit.ly/2xAuP5t includes data of 569 breast cancer patients. In detail, first column is PatientID, second column is the Diagnosis (Malignant/Begnin), while the remaining column 3-32 consists of 3 groups of 10 histological descriptors of tumoral cells; for each descriptor, its Average, StandardError and Worst Case are listed.
# Using the 30 descriptor columns, project using t-SNE the 569 patients on a 2D space and color them according to their diagnosis. Are the two different diagnoses well separated in the 2D space?
# Repeat the same procedure using only the last 10 Worst Case columns: is the separation between diagnoses improving or worsening?__

# %%
data_f = pd.read_csv('WisconsinBreastCancer.csv')

# %%
data_f
# Out:
#      patient ID patient diagnosis  Average radius  Average texture  \
# 0        842302                 M           17.99            10.38
# 1        842517                 M           20.57            17.77
# 2      84300903                 M           19.69            21.25
# 3      84348301                 M           11.42            20.38
# 4      84358402                 M           20.29            14.34
# ..          ...               ...             ...              ...
# 564      926424                 M           21.56            22.39
# 565      926682                 M           20.13            28.25
# 566      926954                 M           16.60            28.08
# 567      927241                 M           20.60            29.33
# 568       92751                 B            7.76            24.54
#
#      Average perimeter  Average area  Average smoothness  Average compactness  \
# 0               122.80        1001.0             0.11840              0.27760
# ...

# %%
from __future__ import print_function
import time
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_openml
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
len(data_f)
data_f_labels = data_f['patient diagnosis'].to_list()

# %%
y = [1 if data_f['patient diagnosis'][x] == 'M' else 0 for x in range(len(data_f))]

# %%
df_subset = data_f.iloc[:,2:]
df_subset['y'] = y
df_subset
# Out:
#      Average radius  Average texture  Average perimeter  Average area  \
# 0             17.99            10.38             122.80        1001.0
# 1             20.57            17.77             132.90        1326.0
# 2             19.69            21.25             130.00        1203.0
# 3             11.42            20.38              77.58         386.1
# 4             20.29            14.34             135.10        1297.0
# ..              ...              ...                ...           ...
# 564           21.56            22.39             142.00        1479.0
# 565           20.13            28.25             131.20        1261.0
# 566           16.60            28.08             108.30         858.1
# 567           20.60            29.33             140.10        1265.0
# 568            7.76            24.54              47.92         181.0
#
#      Average smoothness  Average compactness  Average concavity  \
# ...

# %%
time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(df_subset)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 569 samples in 0.010s...
# [t-SNE] Computed neighbors for 569 samples in 0.048s...
# [t-SNE] Computed conditional probabilities for sample 569 / 569
# [t-SNE] Mean sigma: 33.679842
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 49.850956
# [t-SNE] KL divergence after 300 iterations: 0.323328
# t-SNE done! Time elapsed: 2.3511950969696045 seconds

# %%
df_subset['Patient Diagnosis'] = data_f_labels

# %%
df_subset['tsne-2d-one'] = tsne_results[:,0]
df_subset['tsne-2d-two'] = tsne_results[:,1]
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue='Patient Diagnosis',
    palette=sns.color_palette("hls", 2),
    data=df_subset,
    legend="full",
    alpha=0.3
)

# %%
data_f = pd.read_csv('WisconsinBreastCancer.csv')

# %%
data_f.columns
# Out:
# Index(['patient ID', 'patient diagnosis', 'Average radius', 'Average texture',
#        'Average perimeter', 'Average area', 'Average smoothness',
#        'Average compactness', 'Average concavity', 'Average concave points',
#        'Average symmetry', 'Average fractal dimension', 'SE radius',
#        'SE texture', 'SE perimeter', 'SE area', 'SE smoothness',
#        'SE compactness', 'SE concavity', 'SE concave points', 'SE symmetry',
#        'SE fractal dimension', 'Worst radius', 'Worst texture',
#        'Worst perimeter', 'Worst area', 'Worst smoothness',
#        'Worst compactness', 'Worst concavity', 'Worst concave points',
#        'Worst symmetry', 'Worst fractal dimension'],
#       dtype='object')

# %%
i = 0 
for c  in data_f.columns: 
    if 'Worst' in c :
        break
    i += 1 
i
# Out:
# 22

# %%
df_red2 = data_f.iloc[:,i:]
df_red2['y'] = y

# %%
time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(df_red2)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 569 samples in 0.002s...
# [t-SNE] Computed neighbors for 569 samples in 0.018s...
# [t-SNE] Computed conditional probabilities for sample 569 / 569
# [t-SNE] Mean sigma: 16.947595
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 46.140663
# [t-SNE] KL divergence after 300 iterations: 0.200934
# t-SNE done! Time elapsed: 1.1957638263702393 seconds

# %%
df_red2['Patient Diagnosis'] = data_f_labels
df_red2['tsne-2d-one'] = tsne_results[:,0]
df_red2['tsne-2d-two'] = tsne_results[:,1]
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue='Patient Diagnosis',
    palette=sns.color_palette("hls", 2),
    data=df_red2,
    legend="full",
    alpha=0.3
)

# %% [markdown]
# With this second t-SNE we have improved our abilty to cluster patients. Indeed, with this second plot we see less overlaping of points and a better distintion of the two culsters.
# This can be explained by the fact that we are now considering variable that are most relevant and contain an high amount of informmation (variability)

# %% [markdown]
# __Using the datafile http://bit.ly/2JuGyIu , replicate the following plot__

# %%
df = pd.read_csv('plotdata.csv')

# %%
df
# Out:
#        x    Fit  lower_CI  upper_CI
# 0    1.0   1.00      0.00      2.00
# 1    1.5   2.71      1.81      3.61
# 2    2.0   4.24      3.44      5.04
# 3    2.5   5.59      4.89      6.29
# 4    3.0   6.76      6.16      7.36
# 5    3.5   7.75      7.25      8.25
# 6    4.0   8.56      8.16      8.96
# 7    4.5   9.19      8.89      9.49
# 8    5.0   9.64      9.44      9.84
# 9    5.5   9.91      9.81     10.01
# 10   6.0  10.00     10.00     10.00
# 11   6.5   9.91      9.81     10.01
# 12   7.0   9.64      9.44      9.84
# 13   7.5   9.19      8.89      9.49
# 14   8.0   8.56      8.16      8.96
# 15   8.5   7.75      7.25      8.25
# 16   9.0   6.76      6.16      7.36
# 17   9.5   5.59      4.89      6.29
# 18  10.0   4.24      3.44      5.04
# 19  10.5   2.71      1.81      3.61
# 20  11.0   1.00      0.00      2.00

# %%
fig = plt.figure(figsize=(25, 10), dpi= 50, facecolor='w', edgecolor='k')  
plt.plot('x', 'Fit', data = df, label = 'Fit', color = '#006680', linewidth = 2)
plt.fill_between('x', 'lower_CI', 'upper_CI', color="#006680", alpha=0.5, data = df, label ='95% Fit')
plt.title('Line for best fit for number of checks outs vs Temperature', size = 40)
plt.legend(prop={'size': 20})
plt.xticks(size = 20)
plt.yticks(size =20)
plt.xlabel('Check outs', size = 20)
plt.ylabel('Normalized temperature', size = 20)
plt.tick_params(length = 10)
